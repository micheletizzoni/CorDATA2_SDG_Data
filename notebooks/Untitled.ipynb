# %%
import wbdata

# %%
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
indicators = {'SI.POV.UMIC':'Poverty headcount ratio at $5.50 a day (2011 PPP)'}

# %%
df = wbdata.get_dataframe(indicators, convert_date=False)

# %%
dfu = df.unstack(level=0)

# %%
dfu
# Out:
#         Poverty headcount ratio at $5.50 a day (2011 PPP)                  \
# country                                       Afghanistan Albania Algeria
# date
# 1960                                                  NaN     NaN     NaN
# 1961                                                  NaN     NaN     NaN
# 1962                                                  NaN     NaN     NaN
# 1963                                                  NaN     NaN     NaN
# 1964                                                  NaN     NaN     NaN
# ...                                                   ...     ...     ...
# 2016                                                  NaN    34.2     NaN
# 2017                                                  NaN    33.8     NaN
# 2018                                                  NaN     NaN     NaN
# 2019                                                  NaN     NaN     NaN
# 2020                                                  NaN     NaN     NaN
#
# ...

# %%
plt.figure(figsize=(25,20))
dfu.plot()
